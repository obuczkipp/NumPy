# %% [markdown]
# # Pandas Introduction

# %% [markdown]
# ## Data Analyst Section

# %%
import pandas as pd

# %% [markdown]
# ## 2 Main Data Types

# %%
serial = pd.Series(["BMW", "Toyota", "Honda"])

# %%
serial
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %% [markdown]
# ### series = 1 dimensonal

# %%
colours = pd.Series(["red", "orange", "blue"])
colours
# Out:
# 0       red
# 1    orange
# 2      blue
# dtype: object

# %% [markdown]
# DataFrame = 2 dimensional

# %% [markdown]
# Create a DataFrame from Series

# %% [markdown]
# # DataFrame = 2 Dimensional

# %%
car_df = pd.DataFrame({"type":serial, "colour":colours})

# %%
car_df
# Out:
#      type  colour
# 0     BMW     red
# 1  Toyota  orange
# 2   Honda    blue

# %%
# Import Data

df = pd.read_excel("Adidas_US_Sales_Datasets (5).xlsx")

# %%
df
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %%
# exporting data frame

# %%
df.to_csv("Sales_Datasets.csv", index = False)

# %%
exported_sales_df = pd.read_csv("Sales_Datasets.csv")

# %%
exported_sales_df
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %% [markdown]
# # Describe Data

# %%
#Attribute

df.dtypes

# Function () 
#df.to_csv()
# Out:
# Retailer                    object
# Retailer ID                  int64
# Invoice Date        datetime64[ns]
# Region                      object
# State                       object
# City                        object
# Product                     object
# Price per Unit             float64
# Units Sold                   int64
# Total Sales                float64
# Operating Profit           float64
# Operating Margin           float64
# Sales Method                object
# dtype: object

# %% [markdown]
# ### read columns

# %%
df.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per Unit', 'Units Sold', 'Total Sales',
#        'Operating Profit', 'Operating Margin', 'Sales Method'],
#       dtype='object')

# %% [markdown]
# # read index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9648, step=1)

# %% [markdown]
# # describe function

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df
# Out:
#          Retailer  Retailer_ID Invoice_Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                    Product  Price_per_Unit  Units_Sold  \
# ...

# %% [markdown]
# # Describe function only works with numeric variabels

# %%
df.Price_per_Unit.describe()
# Out:
# count    9648.000000
# mean       45.216625
# std        14.705397
# min         7.000000
# 25%        35.000000
# 50%        45.000000
# 75%        55.000000
# max       110.000000
# Name: Price_per_Unit, dtype: float64

# %%
df.columns = df.columns.str.lower()

# %%
# Overview our df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          9648 non-null   object
#  1   retailer_id       9648 non-null   int64
#  2   invoice_date      9648 non-null   datetime64[ns]
#  3   region            9648 non-null   object
#  4   state             9648 non-null   object
#  5   city              9648 non-null   object
#  6   product           9648 non-null   object
#  7   price_per_unit    9648 non-null   float64
#  8   units_sold        9648 non-null   int64
#  9   total_sales       9648 non-null   float64
#  10  operating_profit  9648 non-null   float64
#  11  operating_margin  9648 non-null   float64
#  12  sales_method      9648 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(6)
# memory usage: 980.0+ KB

# %%
# Mean

# %%
df.price_per_unit.mean()
# Out:
# 45.21662520729685

# %%
car_prices = pd.Series( [300, 5000, 7000])
car_prices.mean()
# Out:
# 4100.0

# %%
df.price_per_unit.sum()
# Out:
# 436250.0

# %%
df["price_per_unit"].sum()
# Out:
# 436250.0

# %%
#length of df

# %%
len(df)
# Out:
# 9648

# %%
sum(df.price_per_unit)
# Out:
# 436250.0

# %%
min(df.price_per_unit)
# Out:
# 7.0

# %%
max(df.price_per_unit)
# Out:
# 110.00000000000001

# %% [markdown]
# # Selecting and Viewing Data

# %%
df.head(7)
# Out:
#       retailer  retailer_id invoice_date     region     state      city  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
# 5  Foot Locker      1185732   2020-01-06  Northeast  New York  New York
# 6  Foot Locker      1185732   2020-01-07  Northeast  New York  New York
#
#                      product  price_per_unit  units_sold  total_sales  \
# 0      Men's Street Footwear            50.0        1200     600000.0
# 1    Men's Athletic Footwear            50.0        1000     500000.0
# 2    Women's Street Footwear            40.0        1000     400000.0
# 3  Women's Athletic Footwear            45.0         850     382500.0
# ...

# %% [markdown]
# # If you want see the end of the df

# %%
df.tail()
# Out:
#          retailer  retailer_id invoice_date     region          state  \
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             city                  product  price_per_unit  units_sold  \
# 9643  Manchester            Men's Apparel            50.0          64
# 9644  Manchester          Women's Apparel            41.0         105
# 9645  Manchester    Men's Street Footwear            41.0         184
# 9646  Manchester  Men's Athletic Footwear            42.0          70
# 9647  Manchester  Women's Street Footwear            29.0          83
#
#       total_sales  operating_profit  operating_margin sales_method
# ...

# %%
# loc & iloc

animals = pd.Series(["cat", "dog", "bird", "elephant"])

# %%
animals
# Out:
# 0         cat
# 1         dog
# 2        bird
# 3    elephant
# dtype: object

# %%
animals = pd.Series(["cat", "dog", "bird", "elephant"], index = [1,3,6,9])

# %%
animals
# Out:
# 1         cat
# 3         dog
# 6        bird
# 9    elephant
# dtype: object

# %%
# loc refers the index number

# %%
animals.loc[3]
# Out:
# 'dog'

# %%
# iloc give us the position not the index

df.iloc[9]
# Out:
# retailer                          Foot Locker
# retailer_id                           1185732
# invoice_date              2020-01-22 00:00:00
# region                              Northeast
# state                                New York
# city                                 New York
# product             Women's Athletic Footwear
# price_per_unit                           45.0
# units_sold                                825
# total_sales                          371250.0
# operating_profit                     129937.5
# operating_margin                         0.35
# sales_method                           Outlet
# Name: 9, dtype: object

# %%
# if we want sliceing : menas up to this index show everithing

# %%
animals.loc[:6]
# Out:
# 1     cat
# 3     dog
# 6    bird
# dtype: object

# %%
animals.iloc[:2]
# Out:
# 1    cat
# 3    dog
# dtype: object

# %%
# Filter a Coulmn

# %%
df.head()
# Out:
#       retailer  retailer_id invoice_date     region     state      city  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
#
#                      product  price_per_unit  units_sold  total_sales  \
# 0      Men's Street Footwear            50.0        1200     600000.0
# 1    Men's Athletic Footwear            50.0        1000     500000.0
# 2    Women's Street Footwear            40.0        1000     400000.0
# 3  Women's Athletic Footwear            45.0         850     382500.0
# 4              Men's Apparel            60.0         900     540000.0
#
#    operating_profit  operating_margin sales_method
# 0          300000.0              0.50     In-store
# ...

# %%
df[df["region"] == "Northeast"] ## this is a filtered row or range
# Out:
#          retailer  retailer_id invoice_date     region          state  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             city                    product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# # Crosstable from columns

# %%
pd.crosstab(df["state"], df["operating_profit"])
# Out:
# operating_profit  0.00       75.20      93.38      107.59     112.00     \
# state
# Alabama                   0          0          0          0          0
# Alaska                    0          0          0          0          0
# Arizona                   0          0          0          0          0
# Arkansas                  0          0          0          0          0
# California                0          0          0          0          0
# Colorado                  0          0          0          0          0
# Connecticut               0          0          0          0          0
# Delaware                  0          0          0          0          0
# Florida                   0          0          0          0          0
# Georgia                   0          0          0          0          0
# Hawaii                    0          0          0          0          0
# Idaho                     0          0          0          0          0
# ...

# %%
# cross tab the first variable gonna be row, secound gonna be coloumn / count row

# %%
pd.crosstab([df.region], [df.total_sales])
# Out:
# total_sales  0.0       160.0     203.0     224.0     232.0     238.0     \
# region
# Midwest             4         0         1         2         0         1
# Northeast           0         1         1         0         1         0
# South               0         0         0         0         0         0
# Southeast           0         0         0         0         0         0
# West                0         0         0         0         0         0
#
# total_sales  252.0     256.0     259.0     280.0     ...  732000.0  735000.0  \
# region                                               ...
# Midwest             1         0         1         1  ...         0         0
# Northeast           0         1         0         0  ...         1         0
# South               0         0         0         0  ...         0         0
# Southeast           0         0         0         0  ...         0         1
# West                0         0         0         0  ...         0         1
#
# ...

# %%
car_df
# Out:
#      type  colour
# 0     BMW     red
# 1  Toyota  orange
# 2   Honda    blue

# %%
car_df.groupby(["type"])

# %%
import matplotlib.pyplot as plt

# %%
df["units_sold"].plot()
# Out:
# <Axes: >

# %%
df["units_sold"].hist()
# Out:
# <Axes: >

# %%
df["operating_profit"].dtype
# Out:
# dtype('float64')

# %%
df["operating_profit"].plot()
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          9648 non-null   object
#  1   retailer_id       9648 non-null   int64
#  2   invoice_date      9648 non-null   datetime64[ns]
#  3   region            9648 non-null   object
#  4   state             9648 non-null   object
#  5   city              9648 non-null   object
#  6   product           9648 non-null   object
#  7   price_per_unit    9648 non-null   float64
#  8   units_sold        9648 non-null   int64
#  9   total_sales       9648 non-null   float64
#  10  operating_profit  9648 non-null   float64
#  11  operating_margin  9648 non-null   float64
#  12  sales_method      9648 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(6)
# memory usage: 980.0+ KB

# %%
df.region = df.region.astype

# %%
df.region.dtype
# Out:
# dtype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          9648 non-null   object
#  1   retailer_id       9648 non-null   int64
#  2   invoice_date      9648 non-null   datetime64[ns]
#  3   region            9648 non-null   object
#  4   state             9648 non-null   object
#  5   city              9648 non-null   object
#  6   product           9648 non-null   object
#  7   price_per_unit    9648 non-null   float64
#  8   units_sold        9648 non-null   int64
#  9   total_sales       9648 non-null   float64
#  10  operating_profit  9648 non-null   float64
#  11  operating_margin  9648 non-null   float64
#  12  sales_method      9648 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(6)
# memory usage: 980.0+ KB

# %% [markdown]
# ## Manipulate Data

# %%
df.head()
# Out:
#       retailer  retailer_id invoice_date  \
# 0  Foot Locker      1185732   2020-01-01
# 1  Foot Locker      1185732   2020-01-02
# 2  Foot Locker      1185732   2020-01-03
# 3  Foot Locker      1185732   2020-01-04
# 4  Foot Locker      1185732   2020-01-05
#
#                                               region     state      city  \
# 0  <bound method NDFrame.astype of 0       Northe...  New York  New York
# 1  <bound method NDFrame.astype of 0       Northe...  New York  New York
# 2  <bound method NDFrame.astype of 0       Northe...  New York  New York
# 3  <bound method NDFrame.astype of 0       Northe...  New York  New York
# 4  <bound method NDFrame.astype of 0       Northe...  New York  New York
#
#                      product  price_per_unit  units_sold  total_sales  \
# 0      Men's Street Footwear            50.0        1200     600000.0
# 1    Men's Athletic Footwear            50.0        1000     500000.0
# ...

# %%
df["state"] = df["state"].str.lower()

# %%
df.head()
# Out:
#       retailer  retailer_id invoice_date  \
# 0  Foot Locker      1185732   2020-01-01
# 1  Foot Locker      1185732   2020-01-02
# 2  Foot Locker      1185732   2020-01-03
# 3  Foot Locker      1185732   2020-01-04
# 4  Foot Locker      1185732   2020-01-05
#
#                                               region     state      city  \
# 0  <bound method NDFrame.astype of 0       Northe...  new york  New York
# 1  <bound method NDFrame.astype of 0       Northe...  new york  New York
# 2  <bound method NDFrame.astype of 0       Northe...  new york  New York
# 3  <bound method NDFrame.astype of 0       Northe...  new york  New York
# 4  <bound method NDFrame.astype of 0       Northe...  new york  New York
#
#                      product  price_per_unit  units_sold  total_sales  \
# 0      Men's Street Footwear            50.0        1200     600000.0
# 1    Men's Athletic Footwear            50.0        1000     500000.0
# ...

# %%
missing_values = pd.read_excel("Missing_vales_sales_data.xlsx")

# %%
missing_values
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                    Product Price per Unit Units Sold  \
# ...

# %%
df.operating_profit.mean()
# Out:
# 34425.244760572146

# %%
df.operating_margin.hist()
# Out:
# <Axes: >

# %% [markdown]
# # Manuipulating Data

# %%
df.dropna()
# Out:
#          retailer  retailer_id invoice_date  \
# 0     Foot Locker      1185732   2020-01-01
# 1     Foot Locker      1185732   2020-01-02
# 2     Foot Locker      1185732   2020-01-03
# 3     Foot Locker      1185732   2020-01-04
# 4     Foot Locker      1185732   2020-01-05
# ...           ...          ...          ...
# 9643  Foot Locker      1185732   2021-01-24
# 9644  Foot Locker      1185732   2021-01-24
# 9645  Foot Locker      1185732   2021-02-22
# 9646  Foot Locker      1185732   2021-02-22
# 9647  Foot Locker      1185732   2021-02-22
#
#                                                  region          state  \
# 0     <bound method NDFrame.astype of 0       Northe...       new york
# 1     <bound method NDFrame.astype of 0       Northe...       new york
# 2     <bound method NDFrame.astype of 0       Northe...       new york
# 3     <bound method NDFrame.astype of 0       Northe...       new york
# 4     <bound method NDFrame.astype of 0       Northe...       new york
# ...

# %% [markdown]
# # Azoknak a soroknak a megjelenítése, amelyek tartalmaznak NaN értéket
# nan_rows = df[df.isna().any(axis=1)]
# print(nan_rows)

# %%
nan_rows = missing_values[missing_values.isna().any(axis=1)]
print(nan_rows)
# Out:
# Empty DataFrame
# Columns: [Retailer, Retailer ID, Invoice Date, Region, State, City, Product, Price per Unit, Units Sold, Total Sales, Operating Profit, Operating Margin, Sales Method]
# Index: []

# %%
nan_rows
# Out:
# Empty DataFrame
# Columns: [Retailer, Retailer ID, Invoice Date, Region, State, City, Product, Price per Unit, Units Sold, Total Sales, Operating Profit, Operating Margin, Sales Method]
# Index: []

# %%
print(nan_rows)
# Out:
# Empty DataFrame
# Columns: [Retailer, Retailer ID, Invoice Date, Region, State, City, Product, Price per Unit, Units Sold, Total Sales, Operating Profit, Operating Margin, Sales Method]
# Index: []

# %%
missing_values.head(100)
# Out:
#        Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0   Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1   Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2   Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3   Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4   Foot Locker      1185732   2020-01-05  Northeast  New York  New York
# ..          ...          ...          ...        ...       ...       ...
# 95      Walmart      1197831   2020-08-15      South     Texas   Houston
# 96      Walmart      1197831   2020-08-16      South     Texas   Houston
# 97      Walmart      1197831   2020-08-17      South     Texas   Houston
# 98      Walmart      1197831   2020-08-18      South     Texas   Houston
# 99      Walmart      1197831   2020-08-19      South     Texas   Houston
#
#                       Product Price per Unit Units Sold Total Sales  \
# ...

# %% [markdown]
# # Fill the missing values in entire dataframe

# %%
df_filled = missing_values.fillna(0)

# %%
df_filled
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                    Product Price per Unit Units Sold  \
# ...

# %% [markdown]
# # Manipulating Data 2

# %%
df_m = pd.DataFrame({
    'A': [1, 2, None, 4],
    'B': [None, 2, 3, 4],
    'C': [1, None, 3, 4]
})

# %%
df_m
# Out:
#      A    B    C
# 0  1.0  NaN  1.0
# 1  2.0  2.0  NaN
# 2  NaN  3.0  3.0
# 3  4.0  4.0  4.0

# %% [markdown]
# # Create a New colmn

# %%
New = pd.Series([100, 200, 600, 900, 500])

# %%
df_m["New_Column"] = New

# %%
df_m
# Out:
#      A    B    C  New_Column
# 0  1.0  NaN  1.0         100
# 1  2.0  2.0  NaN         200
# 2  NaN  3.0  3.0         600
# 3  4.0  4.0  4.0         900

# %% [markdown]
# # Fill Missing Values with another Mean Values / inplace = True parameter is going to overwrite

# %%
df_m.fillna(df_m.New_Column.mean(), inplace = True)

# %% [markdown]
# # If You create a new column from python list, Must have the same row number...

# %%
Secound_column = [74, 73, 72, 100]

# %%
df_m["2nd_Col"] = Secound_column

# %%
df_m
# Out:
#        A      B      C  New_Column  2nd_Col
# 0    1.0  450.0    1.0         100       74
# 1    2.0    2.0  450.0         200       73
# 2  450.0    3.0    3.0         600       72
# 3    4.0    4.0    4.0         900      100

# %%
# Adatok létrehozása
data = {
    'Brand': ['Toyota', 'Ford', 'BMW', 'Audi'],
    'Consumption': [7.5, 8.0, 9.5, 10.0],  # liters per 100 km
    'Price': [20000, 25000, 35000, 40000],  # in USD
    'Mileage': [50000, 60000, 30000, 40000],  # in km
    'Fuel per 100 km': [7.5, 8.0, 9.5, 10.0]  # liters per 100 km
}

# DataFrame létrehozása
car_df = pd.DataFrame(data)

# DataFrame megjelenítése
car_df
# Out:
#     Brand  Consumption  Price  Mileage  Fuel per 100 km
# 0  Toyota          7.5  20000    50000              7.5
# 1    Ford          8.0  25000    60000              8.0
# 2     BMW          9.5  35000    30000              9.5
# 3    Audi         10.0  40000    40000             10.0

# %%
car_df.columns = car_df.columns.str.replace(' ', '_')

# %%
car_df
# Out:
#     Brand  Consumption  Price  Mileage  Fuel_per_100_km
# 0  Toyota          7.5  20000    50000              7.5
# 1    Ford          8.0  25000    60000              8.0
# 2     BMW          9.5  35000    30000              9.5
# 3    Audi         10.0  40000    40000             10.0

# %% [markdown]
# # Create a new Calculated column

# %%
car_df["LiftimeCons"] = ((car_df.Mileage / 100 ) * (car_df.Fuel_per_100_km))

# %%
car_df
# Out:
#     Brand  Consumption  Price  Mileage  Fuel_per_100_km  LiftimeCons
# 0  Toyota          7.5  20000    50000              7.5       3750.0
# 1    Ford          8.0  25000    60000              8.0       4800.0
# 2     BMW          9.5  35000    30000              9.5       2850.0
# 3    Audi         10.0  40000    40000             10.0       4000.0

# %% [markdown]
# # Create a Column from a single Value

# %%
car_df["Wheels"] = (4)

# %%
car_df
# Out:
#     Brand  Consumption  Price  Mileage  Fuel_per_100_km  LiftimeCons  Wheels
# 0  Toyota          7.5  20000    50000              7.5       3750.0       4
# 1    Ford          8.0  25000    60000              8.0       4800.0       4
# 2     BMW          9.5  35000    30000              9.5       2850.0       4
# 3    Audi         10.0  40000    40000             10.0       4000.0       4

# %%
# Create a True / False Column Boolien

# %%
car_df["Boolien_Col"] = True

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            4 non-null      object
#  1   Consumption      4 non-null      float64
#  2   Price            4 non-null      int64
#  3   Mileage          4 non-null      int64
#  4   Fuel_per_100_km  4 non-null      float64
#  5   LiftimeCons      4 non-null      float64
#  6   Wheels           4 non-null      int64
#  7   Boolien_Col      4 non-null      bool
# dtypes: bool(1), float64(3), int64(3), object(1)
# memory usage: 360.0+ bytes

# %% [markdown]
# # Drop out a specific column

# %% [markdown]
# image_path = py_df.jpg
# Image(py_df.jpg)

# %%
# !py_df.jpg
# Out:
# ^C

# %% [markdown]
# ## To be Done with Drop Out, We have to reassign df = df.drop("Price) OR USING THE INPLACE = TRUE METHOD

# %%
car_df.drop("Price", axis = 1, inplace = True)

# %%
print(car_df)
# Out:
#     Brand  Consumption  Mileage  Fuel_per_100_km  LiftimeCons  Wheels  \
# 0  Toyota          7.5    50000              7.5       3750.0       4
# 1    Ford          8.0    60000              8.0       4800.0       4
# 2     BMW          9.5    30000              9.5       2850.0       4
# 3    Audi         10.0    40000             10.0       4000.0       4
#
#    Boolien_Col
# 0         True
# 1         True
# 2         True
# 3         True

# %% [markdown]
# # Manipulating Data 3

# %% [markdown]
# # Before the Modeling: We need to mix the rows to avoid infulence our model

# %% [markdown]
# ## Randomizing our dataframe 100% or below exmpl: 30%

# %%
df.sample(frac = 0.3)
# Out:
#            retailer  retailer_id invoice_date  \
# 6951    Foot Locker      1185732   2021-09-07
# 4922    Foot Locker      1185732   2021-06-20
# 5432         Kohl's      1185732   2021-07-10
# 1641    Foot Locker      1128299   2021-12-23
# 1952      West Gear      1128299   2021-03-16
# ...             ...          ...          ...
# 3585    Foot Locker      1185732   2021-12-03
# 312     Foot Locker      1185732   2021-06-28
# 4307  Sports Direct      1197831   2021-10-13
# 7915        Walmart      1197831   2020-10-31
# 4668  Sports Direct      1185732   2020-10-09
#
#                                                  region        state  \
# 6951  <bound method NDFrame.astype of 0       Northe...         iowa
# 4922  <bound method NDFrame.astype of 0       Northe...     nebraska
# 5432  <bound method NDFrame.astype of 0       Northe...      wyoming
# 1641  <bound method NDFrame.astype of 0       Northe...     virginia
# ...

# %%
# 100% Randomizing

df_randomized = df.sample(frac = 1)

# %%
df_randomized
# Out:
#            retailer  retailer_id invoice_date  \
# 8440        Walmart      1128299   2021-05-18
# 7380         Kohl's      1185732   2021-08-07
# 6817    Foot Locker      1185732   2021-10-12
# 1620    Foot Locker      1128299   2021-08-24
# 3852         Amazon      1185732   2021-08-18
# ...             ...          ...          ...
# 6769    Foot Locker      1185732   2021-02-12
# 4831  Sports Direct      1197831   2021-03-21
# 4925    Foot Locker      1185732   2021-06-23
# 2969  Sports Direct      1185732   2021-05-10
# 3061    Foot Locker      1185732   2021-08-06
#
#                                                  region          state  \
# 8440  <bound method NDFrame.astype of 0       Northe...        florida
# 7380  <bound method NDFrame.astype of 0       Northe...     new jersey
# 6817  <bound method NDFrame.astype of 0       Northe...   south dakota
# 1620  <bound method NDFrame.astype of 0       Northe...       virginia
# ...

# %%
# reset the index

# %%
df_randomized_deletedi = df_randomized.reset_index()

# %%
df_randomized_deletedi
# Out:
#       level_0  index       retailer  retailer_id invoice_date  \
# 0           0   8440        Walmart      1128299   2021-05-18
# 1           1   7380         Kohl's      1185732   2021-08-07
# 2           2   6817    Foot Locker      1185732   2021-10-12
# 3           3   1620    Foot Locker      1128299   2021-08-24
# 4           4   3852         Amazon      1185732   2021-08-18
# ...       ...    ...            ...          ...          ...
# 9643     9643   6769    Foot Locker      1185732   2021-02-12
# 9644     9644   4831  Sports Direct      1197831   2021-03-21
# 9645     9645   4925    Foot Locker      1185732   2021-06-23
# 9646     9646   2969  Sports Direct      1185732   2021-05-10
# 9647     9647   3061    Foot Locker      1185732   2021-08-06
#
#                                                  region          state  \
# 0     <bound method NDFrame.astype of 0       Northe...        florida
# 1     <bound method NDFrame.astype of 0       Northe...     new jersey
# ...

# %% [markdown]
#  # Now we have two index parameters also we have to remove the randomized form, with inplace  + drop method

# %%
df_randomized_deletedi = df_randomized.reset_index(drop = True, inplace = True)

# %%
df_randomized_deletedi

# %% [markdown]
# # Convert Between Units with Apply

# %%
car_df
# Out:
#     Brand  Consumption  Mileage  Fuel_per_100_km  LiftimeCons  Wheels  \
# 0  Toyota          7.5    50000              7.5       3750.0       4
# 1    Ford          8.0    60000              8.0       4800.0       4
# 2     BMW          9.5    30000              9.5       2850.0       4
# 3    Audi         10.0    40000             10.0       4000.0       4
#
#    Boolien_Col
# 0         True
# 1         True
# 2         True
# 3         True

# %%
car_df.Mileage = car_df.Mileage.apply(lambda x: x / 1.6)

# %%
car_df = car_df.rename(columns={'Mileage': 'Mileage (in Miles)'})

# %%
car_df
# Out:
#     Brand  Consumption  Mileage (in Miles)  Fuel_per_100_km  LiftimeCons  \
# 0  Toyota          7.5             31250.0              7.5       3750.0
# 1    Ford          8.0             37500.0              8.0       4800.0
# 2     BMW          9.5             18750.0              9.5       2850.0
# 3    Audi         10.0             25000.0             10.0       4000.0
#
#    Wheels  Boolien_Col
# 0       4         True
# 1       4         True
# 2       4         True
# 3       4         True

# %% [markdown]
# # Assigment: Pandas Practice
